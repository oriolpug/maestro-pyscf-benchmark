# %% [markdown]
# # Full Quantum Chemistry Workflow with Maestro
#
# This notebook walks through a **complete, publication-quality quantum chemistry pipeline** using `qoro-maestro-pyscf`. We'll model BeH₂ (beryllium dihydride) from scratch — starting with the molecule definition and ending with molecular properties.
#
# ### What You'll Learn
#
# 1. How PySCF and Maestro work together
# 2. What each step in a CASSCF calculation does
# 3. How NEVPT2 adds dynamic correlation *for free* on top of VQE
# 4. How to extract molecular properties (dipole moments, natural orbitals) from the quantum simulation
#
# ### Prerequisites
#
# ```bash
# pip install qoro-maestro-pyscf matplotlib
# ```

# %% [markdown]
# ---
#
# ## Step 0: Imports
#
# We need three things:
# - **PySCF** — the classical chemistry engine (molecule, integrals, CASSCF)
# - **MaestroSolver** — our quantum VQE solver that drops into PySCF
# - **Properties** — to compute dipole moments and natural orbitals from the VQE result

# %%
import numpy as np
import time
import matplotlib.pyplot as plt

from pyscf import gto, scf, mcscf, mrpt

from qoro_maestro_pyscf import MaestroSolver
from qoro_maestro_pyscf.properties import (
    compute_dipole_moment,
    compute_natural_orbitals,
)

# Change to "gpu" if you have a Maestro GPU license
BACKEND = "cpu"

# Plot style
plt.rcParams.update({
    'figure.facecolor': '#0d1117',
    'axes.facecolor': '#161b22',
    'axes.edgecolor': '#30363d',
    'axes.labelcolor': '#c9d1d9',
    'text.color': '#c9d1d9',
    'xtick.color': '#8b949e',
    'ytick.color': '#8b949e',
    'grid.color': '#21262d',
    'font.family': 'sans-serif',
    'font.size': 12,
})

# %% [markdown]
# ---
#
# ## Step 1: Define the Molecule
#
# We'll study **BeH₂** — beryllium dihydride in a linear geometry. This molecule is a classic benchmark because:
#
# - At equilibrium, it's well-described by a single Slater determinant
# - But the Be 2s and 2p orbitals are nearly degenerate, creating **multi-reference character**
# - This near-degeneracy is exactly what CASSCF + VQE is designed to handle
#
# We use the minimal STO-3G basis set to keep the quantum circuit small enough to simulate.

# %%
mol = gto.M(
    atom="""
        Be  0.000  0.000  0.000
        H   0.000  0.000  1.334
        H   0.000  0.000 -1.334
    """,
    basis="sto-3g",
    symmetry=False,
    verbose=0,
)

print(f"Atoms          : {mol.natm}")
print(f"Electrons      : {mol.nelectron}")
print(f"Basis functions: {mol.nao_nr()}")
print(f"Spin orbitals  : {2 * mol.nao_nr()}")
# Out:
# Atoms          : 3
# Electrons      : 6
# Basis functions: 7
# Spin orbitals  : 14

# %% [markdown]
# ---
#
# ## Step 2: Hartree-Fock
#
# Hartree-Fock (HF) gives us the **mean-field** approximation — it treats each electron as moving in the average field of all the others. This is fast but misses **electron correlation** (the fact that electrons avoid each other).
#
# The HF result gives us:
# - A reference energy (baseline to improve upon)
# - Molecular orbitals (starting point for CASSCF)

# %%
hf = scf.RHF(mol).run()

print(f"HF energy      : {hf.e_tot:+.10f} Ha")
print(f"HF converged   : {hf.converged}")
# Out:
# HF energy      : -15.5598384372 Ha
# HF converged   : True

# %% [markdown]
# ---
#
# ## Step 3: CASSCF with Maestro VQE
#
# This is **the quantum step**.
#
# ### What is CASSCF?
#
# CASSCF = **Complete Active Space Self-Consistent Field**. It works in two nested loops:
#
# 1. **Inner loop (CI)**: Solve the Schrödinger equation exactly within a small "active space" of orbitals. This is where our VQE runs on Maestro.
# 2. **Outer loop (SCF)**: Rotate the molecular orbitals to minimise the total energy. This uses the **density matrices** (RDMs) from the VQE.
#
# ### Active Space: (2e, 3o)
#
# We put **2 electrons** into **3 orbitals** — the Be 2s, one 2p orbital, and the antibonding combination with H 1s. This gives us **6 qubits** (2 spin-orbitals per spatial orbital).
#
# ```
#      ┌───────────────────────────┐
#      │     Active Space          │
#      │                           │
#   ↑↓ │  ─── σ*        (virtual) │
#      │  ─── 2p         (virtual) │
#   ↑↓ │  ─── 2s/σ    (occupied)  │
#      │                           │
#      └───────────────────────────┘
#   ↑↓    ─── 1s         (frozen core)
# ```
#
# The `MaestroSolver` handles everything:
# - Maps the integrals to a qubit Hamiltonian (Jordan-Wigner)
# - Builds the parameterised quantum circuit (ansatz)
# - Runs VQE optimisation on Maestro's backend
# - Returns density matrices for the CASSCF orbital update

# %%
norb = 3   # active spatial orbitals
nelec = 2  # active electrons

print(f"Active space   : ({nelec}e, {norb}o) → {2 * norb} qubits")

cas = mcscf.CASSCF(hf, norb, nelec)
cas.fcisolver = MaestroSolver(
    ansatz="hardware_efficient",
    ansatz_layers=2,
    backend=BACKEND,
    maxiter=200,
    verbose=True,
)
cas.max_cycle_macro = 15  # limit CASSCF macro-iterations
cas.verbose = 0

t0 = time.perf_counter()
casscf_e = cas.kernel()[0]
casscf_time = time.perf_counter() - t0

print(f"\nCASSCF energy   : {casscf_e:+.10f} Ha")
print(f"Time            : {casscf_time:.1f}s")
# Out:
# Active space   : (2e, 3o) → 6 qubits
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 33
#     iter    1  |  E = +1.0264953747
#     iter   20  |  E = +0.4105283372
#     iter   40  |  E = -0.6381412664
#     iter   60  |  E = -0.7733832101
#     iter   80  |  E = -0.9046671228
#     iter  100  |  E = -0.9871848663
#     iter  120  |  E = -1.0000795119
#     iter  140  |  E = -1.0031279363
#     iter  160  |  E = -1.0100827829
#     iter  180  |  E = -1.0174065966
#     iter  200  |  E = -1.0255133417
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0261586814
#   [MaestroSolver] E(total)  : -15.3097810026
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9930641449
#     iter   20  |  E = +0.3848444215
#     iter   40  |  E = -0.6317831645
#     iter   60  |  E = -0.8122254126
#     iter   80  |  E = -0.9820228657
#     iter  100  |  E = -1.0261722730
#     iter  120  |  E = -1.0338418781
#     iter  140  |  E = -1.0435663444
#     iter  160  |  E = -1.0542855593
#     iter  180  |  E = -1.0599965292
#     iter  200  |  E = -1.0738324877
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0738324877
#   [MaestroSolver] E(total)  : -1.0722138359
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9892268140
#     iter   20  |  E = +0.3822656918
#     iter   40  |  E = -0.6583562322
#     iter   60  |  E = -0.7873547787
#     iter   80  |  E = -0.9691831141
#     iter  100  |  E = -1.0055299040
#     iter  120  |  E = -1.0319015837
#     iter  140  |  E = -1.0356159222
#     iter  160  |  E = -1.0419510032
#     iter  180  |  E = -1.0635832483
#     iter  200  |  E = -1.0741201364
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0741201364
#   [MaestroSolver] E(total)  : -1.0728655145
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9920312487
#     iter   20  |  E = +0.3845455839
#     iter   40  |  E = -0.6558891625
#     iter   60  |  E = -0.7815714786
#     iter   80  |  E = -0.9603298177
#     iter  100  |  E = -1.0329456898
#     iter  120  |  E = -1.0507310123
#     iter  140  |  E = -1.0990877355
#     iter  160  |  E = -1.1290142201
#     iter  180  |  E = -1.1437649683
#     iter  200  |  E = -1.1778902860
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.1778902860
#   [MaestroSolver] E(total)  : -1.1766331320
#   [MaestroSolver] Time      : 0.12s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9909625012
#     iter   20  |  E = +0.3837757179
#     iter   40  |  E = -0.6572652851
#     iter   60  |  E = -0.7863951603
#     iter   80  |  E = -0.9682496480
#     iter  100  |  E = -1.0045758946
#     iter  120  |  E = -1.0308963517
#     iter  140  |  E = -1.0349064529
#     iter  160  |  E = -1.0445386195
#     iter  180  |  E = -1.0601584389
#     iter  200  |  E = -1.0734786559
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0734786559
#   [MaestroSolver] E(total)  : -15.3564279341
#   [MaestroSolver] Time      : 0.12s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9892740050
#     iter   20  |  E = +0.3826963136
#     iter   40  |  E = -0.6577224023
#     iter   60  |  E = -0.7867011585
#     iter   80  |  E = -0.9681378172
#     iter  100  |  E = -1.0048140564
#     iter  120  |  E = -1.0309117558
#     iter  140  |  E = -1.0401528556
#     iter  160  |  E = -1.0442554624
#     iter  180  |  E = -1.0386130050
#     iter  200  |  E = -1.0656765585
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0689954860
#   [MaestroSolver] E(total)  : -1.0685235651
#   [MaestroSolver] Time      : 0.12s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9892911933
#     iter   20  |  E = +0.3827113053
#     iter   40  |  E = -0.6577145051
#     iter   60  |  E = -0.7866897618
#     iter   80  |  E = -0.9681238498
#     iter  100  |  E = -1.0048014372
#     iter  120  |  E = -1.0309001127
#     iter  140  |  E = -1.0401419360
#     iter  160  |  E = -1.0442402240
#     iter  180  |  E = -1.0385524394
#     iter  200  |  E = -1.0388780415
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0784122320
#   [MaestroSolver] E(total)  : -15.3609027658
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9879413874
#     iter   20  |  E = +0.3815883653
#     iter   40  |  E = -0.6582284534
#     iter   60  |  E = -0.7869760486
#     iter   80  |  E = -0.9683904201
#     iter  100  |  E = -1.0047949398
#     iter  120  |  E = -1.0309539989
#     iter  140  |  E = -1.0345271309
#     iter  160  |  E = -1.0551346266
#     iter  180  |  E = -1.0629993644
#     iter  200  |  E = -1.0773777422
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0793030827
#   [MaestroSolver] E(total)  : -1.0794516139
#   [MaestroSolver] Time      : 0.12s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 101
#     iter    1  |  E = +0.9870120216
#     iter   20  |  E = +0.3808890643
#     iter   40  |  E = -0.6369442806
#     iter   60  |  E = -0.8153229617
#     iter   80  |  E = -0.9606723880
#     iter  100  |  E = -0.9745193165
#     iter  120  |  E = -1.0146299161
#     iter  140  |  E = -1.0284007549
#     iter  160  |  E = -1.0376542612
#     iter  180  |  E = -1.0522718689
#     iter  200  |  E = -1.0777152872
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0914174346
#   [MaestroSolver] E(total)  : -1.0916297361
#   [MaestroSolver] Time      : 0.12s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9878008132
#     iter   20  |  E = +0.3815233776
#     iter   40  |  E = -0.6304552483
#     iter   60  |  E = -0.8016913727
#     iter   80  |  E = -0.9928314525
#     iter  100  |  E = -1.0145851413
#     iter  120  |  E = -1.0229572052
#     iter  140  |  E = -1.0329443558
#     iter  160  |  E = -1.0362053182
#     iter  180  |  E = -1.0453311399
#     iter  200  |  E = -1.0511297880
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0511297880
#   [MaestroSolver] E(total)  : -1.0514261091
#   [MaestroSolver] Time      : 0.15s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9872104243
#     iter   20  |  E = +0.3810485548
#     iter   40  |  E = -0.6305618488
#     iter   60  |  E = -0.8018116480
#     iter   80  |  E = -0.9928535767
#     iter  100  |  E = -1.0104282171
#     iter  120  |  E = -1.0296493811
#     iter  140  |  E = -1.0376842963
#     iter  160  |  E = -1.0451308046
#     iter  180  |  E = -1.0526482202
#     iter  200  |  E = -1.0604506433
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0604506433
#   [MaestroSolver] E(total)  : -15.3432216869
#   [MaestroSolver] Time      : 0.14s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9857833449
#     iter   20  |  E = +0.3798500220
#     iter   40  |  E = -0.6316569316
#     iter   60  |  E = -0.8023743130
#     iter   80  |  E = -0.9934386477
#     iter  100  |  E = -1.0111622341
#     iter  120  |  E = -1.0302574358
#     iter  140  |  E = -1.0376497331
#     iter  160  |  E = -1.0445063644
#     iter  180  |  E = -1.0530203354
#     iter  200  |  E = -1.0603685524
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0603685524
#   [MaestroSolver] E(total)  : -1.0598494179
#   [MaestroSolver] Time      : 0.14s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9882539327
#     iter   20  |  E = +0.3818023479
#     iter   40  |  E = -0.6311671477
#     iter   60  |  E = -0.8019897936
#     iter   80  |  E = -0.9934100803
#     iter  100  |  E = -1.0153046747
#     iter  120  |  E = -1.0263338586
#     iter  140  |  E = -1.0337427959
#     iter  160  |  E = -1.0390377175
#     iter  180  |  E = -1.0450803438
#     iter  200  |  E = -1.0527603345
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0527603345
#   [MaestroSolver] E(total)  : -1.0522226940
#   [MaestroSolver] Time      : 0.14s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 113
#     iter    1  |  E = +0.9921968971
#     iter   20  |  E = +0.3848933692
#     iter   40  |  E = -0.6271125805
#     iter   60  |  E = -0.7859422682
#     iter   80  |  E = -0.8957937008
#     iter  100  |  E = -0.9912517360
#     iter  120  |  E = -1.0119939568
#     iter  140  |  E = -1.0252039214
#     iter  160  |  E = -1.0367021917
#     iter  180  |  E = -1.0420582036
#     iter  200  |  E = -1.0477742907
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0477742907
#   [MaestroSolver] E(total)  : -1.0471426373
#   [MaestroSolver] Time      : 0.14s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9861406848
#     iter   20  |  E = +0.3798868070
#     iter   40  |  E = -0.6596575282
#     iter   60  |  E = -0.7881145309
#     iter   80  |  E = -0.9695075196
#     iter  100  |  E = -1.0057180557
#     iter  120  |  E = -1.0105205990
#     iter  140  |  E = -1.0398202847
#     iter  160  |  E = -1.0480068371
#     iter  180  |  E = -1.0563912460
#     iter  200  |  E = -1.0759583556
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0759583556
#   [MaestroSolver] E(total)  : -15.3579870860
#   [MaestroSolver] Time      : 0.12s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9865795115
#     iter   20  |  E = +0.3805049890
#     iter   40  |  E = -0.6588357245
#     iter   60  |  E = -0.7874163310
#     iter   80  |  E = -0.9687156316
#     iter  100  |  E = -1.0049878565
#     iter  120  |  E = -1.0311499549
#     iter  140  |  E = -1.0347167806
#     iter  160  |  E = -1.0552690160
#     iter  180  |  E = -1.0671620562
#     iter  200  |  E = -1.0850915943
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0894880020
#   [MaestroSolver] E(total)  : -1.0899428845
#   [MaestroSolver] Time      : 0.12s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9883619759
#     iter   20  |  E = +0.3819922563
#     iter   40  |  E = -0.6351692850
#     iter   60  |  E = -0.7730146436
#     iter   80  |  E = -0.9491809902
#     iter  100  |  E = -0.9993967637
#     iter  120  |  E = -1.0166166627
#     iter  140  |  E = -1.0292852175
#     iter  160  |  E = -1.0349440652
#     iter  180  |  E = -1.0422201995
#     iter  200  |  E = -1.0498851195
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0498851195
#   [MaestroSolver] E(total)  : -1.0505742227
#   [MaestroSolver] Time      : 0.14s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9883528466
#     iter   20  |  E = +0.3816400345
#     iter   40  |  E = -0.6325391898
#     iter   60  |  E = -0.8125414945
#     iter   80  |  E = -0.9616422277
#     iter  100  |  E = -0.9853277098
#     iter  120  |  E = -1.0053889946
#     iter  140  |  E = -1.0077555873
#     iter  160  |  E = -1.0211089906
#     iter  180  |  E = -1.0269886894
#     iter  200  |  E = -1.0308676063
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0308676063
#   [MaestroSolver] E(total)  : -1.0311614615
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9883550691
#     iter   20  |  E = +0.3816419285
#     iter   40  |  E = -0.6325378301
#     iter   60  |  E = -0.8125396073
#     iter   80  |  E = -0.9616399951
#     iter  100  |  E = -0.9853259635
#     iter  120  |  E = -1.0053872692
#     iter  140  |  E = -1.0077532605
#     iter  160  |  E = -1.0211070043
#     iter  180  |  E = -1.0269863906
#     iter  200  |  E = -1.0308653516
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0308653516
#   [MaestroSolver] E(total)  : -15.3131913840
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9899529975
#     iter   20  |  E = +0.3827789831
#     iter   40  |  E = -0.6355483171
#     iter   60  |  E = -0.7734049427
#     iter   80  |  E = -0.9496274644
#     iter  100  |  E = -1.0003527166
#     iter  120  |  E = -1.0177403847
#     iter  140  |  E = -1.0311316319
#     iter  160  |  E = -1.0374326559
#     iter  180  |  E = -1.0450347425
#     iter  200  |  E = -1.0562152402
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0562152402
#   [MaestroSolver] E(total)  : -1.0560765699
#   [MaestroSolver] Time      : 0.14s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9890240711
#     iter   20  |  E = +0.3821716027
#     iter   40  |  E = -0.6356675065
#     iter   60  |  E = -0.7734548533
#     iter   80  |  E = -0.9496062047
#     iter  100  |  E = -1.0001891374
#     iter  120  |  E = -1.0175155234
#     iter  140  |  E = -1.0307277028
#     iter  160  |  E = -1.0383841162
#     iter  180  |  E = -1.0464818964
#     iter  200  |  E = -1.0585961892
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0585961892
#   [MaestroSolver] E(total)  : -1.0585894206
#   [MaestroSolver] Time      : 0.14s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9877721116
#     iter   20  |  E = +0.3811992287
#     iter   40  |  E = -0.6361891567
#     iter   60  |  E = -0.7737160900
#     iter   80  |  E = -0.9496537598
#     iter  100  |  E = -1.0002053030
#     iter  120  |  E = -1.0212743755
#     iter  140  |  E = -1.0305321890
#     iter  160  |  E = -1.0365042035
#     iter  180  |  E = -1.0438142435
#     iter  200  |  E = -1.0521263393
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0521263393
#   [MaestroSolver] E(total)  : -1.0521788719
#   [MaestroSolver] Time      : 0.14s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9886458014
#     iter   20  |  E = +0.3818530035
#     iter   40  |  E = -0.6308986334
#     iter   60  |  E = -0.8020718821
#     iter   80  |  E = -0.9935791818
#     iter  100  |  E = -1.0113146697
#     iter  120  |  E = -1.0305472030
#     iter  140  |  E = -1.0386122029
#     iter  160  |  E = -1.0448817116
#     iter  180  |  E = -1.0529829535
#     iter  200  |  E = -1.0586326559
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0586326559
#   [MaestroSolver] E(total)  : -15.3409751271
#   [MaestroSolver] Time      : 0.14s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9909424044
#     iter   20  |  E = +0.3837719565
#     iter   40  |  E = -0.6305380272
#     iter   60  |  E = -0.8016512379
#     iter   80  |  E = -0.9934973680
#     iter  100  |  E = -1.0154331808
#     iter  120  |  E = -1.0266731312
#     iter  140  |  E = -1.0339997777
#     iter  160  |  E = -1.0396997160
#     iter  180  |  E = -1.0464786042
#     iter  200  |  E = -1.0524278483
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0524278483
#   [MaestroSolver] E(total)  : -1.0523456412
#   [MaestroSolver] Time      : 0.14s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9969942620
#     iter   20  |  E = +0.3886204433
#     iter   40  |  E = -0.6564757799
#     iter   60  |  E = -0.7998839115
#     iter   80  |  E = -0.9143570411
#     iter  100  |  E = -0.9808596422
#     iter  120  |  E = -0.9969183785
#     iter  140  |  E = -1.0218679825
#     iter  160  |  E = -1.0109192083
#     iter  180  |  E = -1.0381591820
#     iter  200  |  E = -1.0429130336
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0430091012
#   [MaestroSolver] E(total)  : -1.0429084499
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +1.0058579299
#     iter   20  |  E = +0.3956548901
#     iter   40  |  E = -0.6519910970
#     iter   60  |  E = -0.7984887672
#     iter   80  |  E = -0.9517861735
#     iter  100  |  E = -0.9911902865
#     iter  120  |  E = -1.0161441417
#     iter  140  |  E = -1.0269435084
#     iter  160  |  E = -1.0389375680
#     iter  180  |  E = -1.0415289065
#     iter  200  |  E = -1.0489064603
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0489064603
#   [MaestroSolver] E(total)  : -1.0487827806
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +1.1523170952
#     iter   20  |  E = +0.5136957823
#     iter   40  |  E = -0.6379127229
#     iter   60  |  E = -0.8454529026
#     iter   80  |  E = -0.9317242494
#     iter  100  |  E = -1.0091983485
#     iter  120  |  E = -1.0032926145
#     iter  140  |  E = -1.0269625062
#     iter  160  |  E = -1.0363684349
#     iter  180  |  E = -1.0388987769
#     iter  200  |  E = -1.0409707873
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0409707873
#   [MaestroSolver] E(total)  : -15.3230146547
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +1.1420827394
#     iter   20  |  E = +0.5054534694
#     iter   40  |  E = -0.6417331072
#     iter   60  |  E = -0.8497788620
#     iter   80  |  E = -0.9687504925
#     iter  100  |  E = -1.0135091474
#     iter  120  |  E = -1.0097920585
#     iter  140  |  E = -1.0294936880
#     iter  160  |  E = -1.0331500856
#     iter  180  |  E = -1.0360021985
#     iter  200  |  E = -1.0383182509
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0383697014
#   [MaestroSolver] E(total)  : -1.0383772783
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +1.1321793096
#     iter   20  |  E = +0.4974734726
#     iter   40  |  E = -0.6463027132
#     iter   60  |  E = -0.8511008760
#     iter   80  |  E = -0.9687313258
#     iter  100  |  E = -1.0136325060
#     iter  120  |  E = -1.0239991393
#     iter  140  |  E = -1.0280502896
#     iter  160  |  E = -1.0311223114
#     iter  180  |  E = -1.0337713282
#     iter  200  |  E = -1.0352827214
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0352930705
#   [MaestroSolver] E(total)  : -1.0353104089
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +1.0169486811
#     iter   20  |  E = +0.4026758206
#     iter   40  |  E = -0.6310105876
#     iter   60  |  E = -0.8117953404
#     iter   80  |  E = -0.9703810652
#     iter  100  |  E = -0.9867406542
#     iter  120  |  E = -1.0191809482
#     iter  140  |  E = -1.0182568751
#     iter  160  |  E = -1.0397657845
#     iter  180  |  E = -1.0485082818
#     iter  200  |  E = -1.0545939655
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0545939655
#   [MaestroSolver] E(total)  : -1.0548150581
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +1.0003408209
#     iter   20  |  E = +0.3906627983
#     iter   40  |  E = -0.6299829027
#     iter   60  |  E = -0.8120874384
#     iter   80  |  E = -0.9709183950
#     iter  100  |  E = -1.0361059148
#     iter  120  |  E = -1.0249885077
#     iter  140  |  E = -1.0525274286
#     iter  160  |  E = -1.0733688492
#     iter  180  |  E = -1.0934801109
#     iter  200  |  E = -1.1351477513
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.1391053470
#   [MaestroSolver] E(total)  : -15.4213720544
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9950297409
#     iter   20  |  E = +0.3867194004
#     iter   40  |  E = -0.6308459056
#     iter   60  |  E = -0.8119262346
#     iter   80  |  E = -0.9620957760
#     iter  100  |  E = -0.9847250949
#     iter  120  |  E = -1.0033517500
#     iter  140  |  E = -1.0188166747
#     iter  160  |  E = -1.0289029467
#     iter  180  |  E = -1.0359184514
#     iter  200  |  E = -1.0470717402
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0470717402
#   [MaestroSolver] E(total)  : -1.0475421100
#   [MaestroSolver] Time      : 0.14s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9932791282
#     iter   20  |  E = +0.3854782203
#     iter   40  |  E = -0.6366162895
#     iter   60  |  E = -0.8153832126
#     iter   80  |  E = -0.9622162530
#     iter  100  |  E = -0.9735829786
#     iter  120  |  E = -1.0090337063
#     iter  140  |  E = -1.0052396601
#     iter  160  |  E = -1.0399946219
#     iter  180  |  E = -1.0485129130
#     iter  200  |  E = -1.0637981220
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0637981220
#   [MaestroSolver] E(total)  : -1.0636119860
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9881834992
#     iter   20  |  E = +0.3815551784
#     iter   40  |  E = -0.6378537555
#     iter   60  |  E = -0.8158593239
#     iter   80  |  E = -0.9619390052
#     iter  100  |  E = -0.9750288658
#     iter  120  |  E = -1.0152497661
#     iter  140  |  E = -1.0405160976
#     iter  160  |  E = -1.0457124531
#     iter  180  |  E = -1.0515753469
#     iter  200  |  E = -1.0563818926
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0563818926
#   [MaestroSolver] E(total)  : -1.0562619934
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 113
#     iter    1  |  E = +0.9860287903
#     iter   20  |  E = +0.3799566512
#     iter   40  |  E = -0.6383425717
#     iter   60  |  E = -0.8160574594
#     iter   80  |  E = -0.9618327836
#     iter  100  |  E = -0.9751434447
#     iter  120  |  E = -1.0154680776
#     iter  140  |  E = -1.0369390420
#     iter  160  |  E = -1.0427131538
#     iter  180  |  E = -1.0551892841
#     iter  200  |  E = -1.0624346211
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0624346211
#   [MaestroSolver] E(total)  : -15.3445564270
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 113
#     iter    1  |  E = +0.9853581905
#     iter   20  |  E = +0.3794331308
#     iter   40  |  E = -0.6384581852
#     iter   60  |  E = -0.8160799267
#     iter   80  |  E = -0.9617266610
#     iter  100  |  E = -0.9752108470
#     iter  120  |  E = -1.0154488625
#     iter  140  |  E = -1.0370121240
#     iter  160  |  E = -1.0426789966
#     iter  180  |  E = -1.0545670981
#     iter  200  |  E = -1.0572221794
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0575130759
#   [MaestroSolver] E(total)  : -1.0575392379
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 113
#     iter    1  |  E = +0.9849586125
#     iter   20  |  E = +0.3791221012
#     iter   40  |  E = -0.6385005505
#     iter   60  |  E = -0.8160827565
#     iter   80  |  E = -0.9616356530
#     iter  100  |  E = -0.9752438525
#     iter  120  |  E = -1.0154270903
#     iter  140  |  E = -1.0370856265
#     iter  160  |  E = -1.0426358899
#     iter  180  |  E = -1.0545918408
#     iter  200  |  E = -1.0574326268
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0579762846
#   [MaestroSolver] E(total)  : -1.0580126385
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9859845217
#     iter   20  |  E = +0.3799929189
#     iter   40  |  E = -0.6378209311
#     iter   60  |  E = -0.8157732584
#     iter   80  |  E = -0.9612568289
#     iter  100  |  E = -0.9748594490
#     iter  120  |  E = -1.0150990187
#     iter  140  |  E = -1.0288462212
#     iter  160  |  E = -1.0490434779
#     iter  180  |  E = -1.0577450372
#     iter  200  |  E = -1.0651697630
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0651697630
#   [MaestroSolver] E(total)  : -1.0652476242
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9859902372
#     iter   20  |  E = +0.3799987801
#     iter   40  |  E = -0.6378151099
#     iter   60  |  E = -0.8157647205
#     iter   80  |  E = -0.9612474796
#     iter  100  |  E = -0.9748494004
#     iter  120  |  E = -1.0150890277
#     iter  140  |  E = -1.0288372334
#     iter  160  |  E = -1.0490346179
#     iter  180  |  E = -1.0577351626
#     iter  200  |  E = -1.0651594964
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0651594964
#   [MaestroSolver] E(total)  : -15.3473650773
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 109
#     iter    1  |  E = +0.9850526459
#     iter   20  |  E = +0.3792272979
#     iter   40  |  E = -0.6382791954
#     iter   60  |  E = -0.8159400382
#     iter   80  |  E = -0.9614163635
#     iter  100  |  E = -0.9751027236
#     iter  120  |  E = -1.0152536253
#     iter  140  |  E = -1.0370341521
#     iter  160  |  E = -1.0424337403
#     iter  180  |  E = -1.0551325771
#     iter  200  |  E = -1.0620923774
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0620923774
#   [MaestroSolver] E(total)  : -1.0621406824
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 101
#     iter    1  |  E = +0.9846974858
#     iter   20  |  E = +0.3789848346
#     iter   40  |  E = -0.6383436679
#     iter   60  |  E = -0.8159633198
#     iter   80  |  E = -0.9613883931
#     iter  100  |  E = -0.9750582300
#     iter  120  |  E = -1.0151930370
#     iter  140  |  E = -1.0369864939
#     iter  160  |  E = -1.0423339072
#     iter  180  |  E = -1.0554639380
#     iter  200  |  E = -1.0605783041
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0605783041
#   [MaestroSolver] E(total)  : -1.0606062037
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 101
#     iter    1  |  E = +0.9846975103
#     iter   20  |  E = +0.3789848578
#     iter   40  |  E = -0.6383436949
#     iter   60  |  E = -0.8159632091
#     iter   80  |  E = -0.9613883439
#     iter  100  |  E = -0.9750580967
#     iter  120  |  E = -1.0151929263
#     iter  140  |  E = -1.0369863526
#     iter  160  |  E = -1.0423337287
#     iter  180  |  E = -1.0554637802
#     iter  200  |  E = -1.0605781446
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0605781446
#   [MaestroSolver] E(total)  : -15.3428117678
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 109
#     iter    1  |  E = +0.9851238426
#     iter   20  |  E = +0.3793228640
#     iter   40  |  E = -0.6381423700
#     iter   60  |  E = -0.8158810169
#     iter   80  |  E = -0.9613117166
#     iter  100  |  E = -0.9749722315
#     iter  120  |  E = -1.0151365693
#     iter  140  |  E = -1.0287797909
#     iter  160  |  E = -1.0489515384
#     iter  180  |  E = -1.0550261468
#     iter  200  |  E = -1.0634152399
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0634152399
#   [MaestroSolver] E(total)  : -1.0634165000
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 101
#     iter    1  |  E = +0.9848129279
#     iter   20  |  E = +0.3790667899
#     iter   40  |  E = -0.6383113030
#     iter   60  |  E = -0.8159504143
#     iter   80  |  E = -0.9613861574
#     iter  100  |  E = -0.9750619238
#     iter  120  |  E = -1.0152019383
#     iter  140  |  E = -1.0370006274
#     iter  160  |  E = -1.0423506896
#     iter  180  |  E = -1.0554814247
#     iter  200  |  E = -1.0605986565
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0605986565
#   [MaestroSolver] E(total)  : -1.0606052120
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9864106641
#     iter   20  |  E = +0.3803501399
#     iter   40  |  E = -0.6376155546
#     iter   60  |  E = -0.8156714516
#     iter   80  |  E = -0.9611731964
#     iter  100  |  E = -0.9739094691
#     iter  120  |  E = -1.0064972059
#     iter  140  |  E = -1.0226099706
#     iter  160  |  E = -1.0385810950
#     iter  180  |  E = -1.0466871870
#     iter  200  |  E = -1.0533336591
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0533855540
#   [MaestroSolver] E(total)  : -1.0533889732
#   [MaestroSolver] Time      : 0.14s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9864105399
#     iter   20  |  E = +0.3803500514
#     iter   40  |  E = -0.6376155726
#     iter   60  |  E = -0.8156714722
#     iter   80  |  E = -0.9611731905
#     iter  100  |  E = -0.9739094937
#     iter  120  |  E = -1.0064972409
#     iter  140  |  E = -1.0226099421
#     iter  160  |  E = -1.0385810879
#     iter  180  |  E = -1.0466871852
#     iter  200  |  E = -1.0533336628
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0533855548
#   [MaestroSolver] E(total)  : -15.3356225984
#   [MaestroSolver] Time      : 0.14s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9861061230
#     iter   20  |  E = +0.3800965747
#     iter   40  |  E = -0.6377578812
#     iter   60  |  E = -0.8157361228
#     iter   80  |  E = -0.9612226001
#     iter  100  |  E = -0.9748056873
#     iter  120  |  E = -1.0150542487
#     iter  140  |  E = -1.0287985449
#     iter  160  |  E = -1.0489987404
#     iter  180  |  E = -1.0576926579
#     iter  200  |  E = -1.0651157631
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0651157631
#   [MaestroSolver] E(total)  : -1.0651011003
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9858508948
#     iter   20  |  E = +0.3798887019
#     iter   40  |  E = -0.6378660372
#     iter   60  |  E = -0.8157792378
#     iter   80  |  E = -0.9612516971
#     iter  100  |  E = -0.9748669077
#     iter  120  |  E = -1.0150919848
#     iter  140  |  E = -1.0288188361
#     iter  160  |  E = -1.0490124829
#     iter  180  |  E = -1.0577143954
#     iter  200  |  E = -1.0651292117
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0651292117
#   [MaestroSolver] E(total)  : -1.0651158907
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +1.2145144395
#     iter   20  |  E = +0.5622454663
#     iter   40  |  E = -0.5962513004
#     iter   60  |  E = -0.8530801306
#     iter   80  |  E = -0.9309049152
#     iter  100  |  E = -0.9621961318
#     iter  120  |  E = -0.9955163202
#     iter  140  |  E = -1.0219103596
#     iter  160  |  E = -1.0269205082
#     iter  180  |  E = -1.0307946914
#     iter  200  |  E = -1.0353938162
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0354322369
#   [MaestroSolver] E(total)  : -1.0355881467
#   [MaestroSolver] Time      : 0.14s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +1.0344542015
#     iter   20  |  E = +0.4187563237
#     iter   40  |  E = -0.6211162261
#     iter   60  |  E = -0.8181299870
#     iter   80  |  E = -0.9338067307
#     iter  100  |  E = -0.9751721361
#     iter  120  |  E = -1.0186203247
#     iter  140  |  E = -1.0251174009
#     iter  160  |  E = -1.0324585255
#     iter  180  |  E = -1.0381413796
#     iter  200  |  E = -1.0451626589
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0452808463
#   [MaestroSolver] E(total)  : -15.3275912240
#   [MaestroSolver] Time      : 0.22s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +1.0338658067
#     iter   20  |  E = +0.4182823094
#     iter   40  |  E = -0.6213131042
#     iter   60  |  E = -0.8181928255
#     iter   80  |  E = -0.9339390439
#     iter  100  |  E = -0.9752406586
#     iter  120  |  E = -1.0186474790
#     iter  140  |  E = -1.0250842635
#     iter  160  |  E = -1.0328056811
#     iter  180  |  E = -1.0383478964
#     iter  200  |  E = -1.0450369324
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0450369324
#   [MaestroSolver] E(total)  : -1.0450361854
#   [MaestroSolver] Time      : 0.14s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9895361509
#     iter   20  |  E = +0.3824409204
#     iter   40  |  E = -0.6370584629
#     iter   60  |  E = -0.8154470451
#     iter   80  |  E = -0.9613154632
#     iter  100  |  E = -0.9749581296
#     iter  120  |  E = -1.0153077246
#     iter  140  |  E = -1.0291495578
#     iter  160  |  E = -1.0493607021
#     iter  180  |  E = -1.0580982017
#     iter  200  |  E = -1.0663400273
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0663400273
#   [MaestroSolver] E(total)  : -1.0662012463
#   [MaestroSolver] Time      : 0.14s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9895361509
#     iter   20  |  E = +0.3824409204
#     iter   40  |  E = -0.6370584629
#     iter   60  |  E = -0.8154470451
#     iter   80  |  E = -0.9613154632
#     iter  100  |  E = -0.9749581296
#     iter  120  |  E = -1.0153077246
#     iter  140  |  E = -1.0291495578
#     iter  160  |  E = -1.0493607021
#     iter  180  |  E = -1.0580982017
#     iter  200  |  E = -1.0663400273
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0663400273
#   [MaestroSolver] E(total)  : -1.0662012463
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9884299807
#     iter   20  |  E = +0.3816359772
#     iter   40  |  E = -0.6373022492
#     iter   60  |  E = -0.8156012469
#     iter   80  |  E = -0.9613157821
#     iter  100  |  E = -0.9751687037
#     iter  120  |  E = -1.0155231527
#     iter  140  |  E = -1.0294992175
#     iter  160  |  E = -1.0384833090
#     iter  180  |  E = -1.0537396420
#     iter  200  |  E = -1.0789872797
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0927672453
#   [MaestroSolver] E(total)  : -15.3749398014
#   [MaestroSolver] Time      : 0.13s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 109
#     iter    1  |  E = +0.9877957736
#     iter   20  |  E = +0.3812009426
#     iter   40  |  E = -0.6374093910
#     iter   60  |  E = -0.8155972931
#     iter   80  |  E = -0.9612543270
#     iter  100  |  E = -0.9751096914
#     iter  120  |  E = -1.0153863498
#     iter  140  |  E = -1.0292171449
#     iter  160  |  E = -1.0382835702
#     iter  180  |  E = -1.0532849599
#     iter  200  |  E = -1.0786933222
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0925040267
#   [MaestroSolver] E(total)  : -1.0926503236
#   [MaestroSolver] Time      : 0.14s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 93
#     iter    1  |  E = +0.9874001686
#     iter   20  |  E = +0.3809606211
#     iter   40  |  E = -0.6374286256
#     iter   60  |  E = -0.8155509037
#     iter   80  |  E = -0.9611710595
#     iter  100  |  E = -0.9749880286
#     iter  120  |  E = -1.0152098093
#     iter  140  |  E = -1.0288726309
#     iter  160  |  E = -1.0380878651
#     iter  180  |  E = -1.0504498832
#     iter  200  |  E = -1.0879468185
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0893179339
#   [MaestroSolver] E(total)  : -1.0896015678
#   [MaestroSolver] Time      : 0.12s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9882986943
#     iter   20  |  E = +0.3818213685
#     iter   40  |  E = -0.6321591285
#     iter   60  |  E = -0.8119930993
#     iter   80  |  E = -0.9613105477
#     iter  100  |  E = -1.0040430280
#     iter  120  |  E = -1.0299955684
#     iter  140  |  E = -1.0420061625
#     iter  160  |  E = -1.0501057330
#     iter  180  |  E = -1.0549805304
#     iter  200  |  E = -1.0683279502
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0683279502
#   [MaestroSolver] E(total)  : -1.0690042024
#   [MaestroSolver] Time      : 0.20s
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9882762844
#     iter   20  |  E = +0.3818010216
#     iter   40  |  E = -0.6321760944
#     iter   60  |  E = -0.8120100801
#     iter   80  |  E = -0.9613281174
#     iter  100  |  E = -1.0040588252
#     iter  120  |  E = -1.0300164551
#     iter  140  |  E = -1.0420264755
#     iter  160  |  E = -1.0500082923
#     iter  180  |  E = -1.0545082328
#     iter  200  |  E = -1.0667138178
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0667138178
#   [MaestroSolver] E(total)  : -15.3495901581
#   [MaestroSolver] Time      : 0.14s
#
# CASSCF energy   : -15.3495901581 Ha
# Time            : 17.5s

# %% [markdown]
# ---
#
# ## Step 4: NEVPT2 — Adding Dynamic Correlation
#
# CASSCF captures **static correlation** (the multi-reference character from near-degenerate orbitals). But it misses **dynamic correlation** — the short-range electron-electron repulsion that comes from the remaining orbitals outside the active space.
#
# **NEVPT2** (N-Electron Valence Perturbation Theory, 2nd order) adds this dynamic part using perturbation theory. It only needs the RDMs from CASSCF — which our VQE already computed.
#
# This step is **purely classical**. The quantum circuit is only involved in Step 3.

# %%
t0 = time.perf_counter()
try:
    nevpt2_corr = mrpt.NEVPT(cas).kernel()
    nevpt2_time = time.perf_counter() - t0
    nevpt2_e = casscf_e + nevpt2_corr
    print(f"ΔE(NEVPT2) = {nevpt2_corr:+.10f} Ha")
    print(f"E(CASSCF+NEVPT2) = {nevpt2_e:+.10f} Ha  ({nevpt2_time:.1f}s)")
except (AssertionError, RuntimeError, TypeError):
    nevpt2_e = None
    print("⚠ NEVPT2 requires a 3-RDM from the CI vector.")
    print("VQE solvers produce circuits, not CI vectors — skipping.")
# Out:
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9880955983
#     iter   20  |  E = +0.3812852769
#     iter   40  |  E = -0.6648642561
#     iter   60  |  E = -0.7738114716
#     iter   80  |  E = -0.9101189722
#     iter  100  |  E = -0.9801008636
#     iter  120  |  E = -1.0113465329
#     iter  140  |  E = -1.0114227788
#     iter  160  |  E = -1.0142128035
#     iter  180  |  E = -1.0184971818
#     iter  200  |  E = -1.0226925426
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0230407190
#   [MaestroSolver] E(total)  : -15.3059170593
#   [MaestroSolver] Time      : 0.14s
# ⚠ NEVPT2 requires a 3-RDM from the CI vector.
# VQE solvers produce circuits, not CI vectors — skipping.

# %% [markdown]
# ---
#
# ## Step 5: Molecular Properties
#
# A bare energy number is rarely enough for a chemist. We need **observables** that connect to experiment.
#
# ### Dipole Moment
#
# The dipole moment $\boldsymbol{\mu}$ tells you how charge is distributed in the molecule. It's computed from the 1-RDM:
#
# $$\mu_x = \sum_{pq} D_{pq} \langle p | x | q \rangle + \text{nuclear contribution}$$
#
# For BeH₂ in a linear symmetric geometry, the dipole should be **zero by symmetry**.
#
# ### Natural Orbital Occupations
#
# Natural orbitals are the eigenvectors of the 1-RDM. Their eigenvalues (occupations) tell you about the correlation in the system:
#
# - **Occupation ≈ 2.0**: doubly occupied, well-described by HF
# - **Occupation ≈ 0.0**: empty, not contributing
# - **Occupation between 0.3 and 1.7**: **fractional** — this orbital is correlated, and you need multi-reference methods

# %%
# Get the 1-RDM from the VQE
ci = cas.ci
rdm1 = cas.fcisolver.make_rdm1(ci, norb, (1, 1))

# Dipole moment
dipole, mag = compute_dipole_moment(mol, cas.mo_coeff, rdm1)
print(f"Dipole moment")
print(f"  x: {dipole[0]:+.6f} D")
print(f"  y: {dipole[1]:+.6f} D")
print(f"  z: {dipole[2]:+.6f} D")
print(f"  |μ| = {mag:.6f} D")
print(f"  (Should be ~0 by symmetry)")

# Natural orbital occupations
occ, _ = compute_natural_orbitals(rdm1)
print(f"\nNatural orbital occupations:")
for i, n in enumerate(occ):
    bar = '█' * int(n * 25)
    label = 'correlated' if 0.3 < n < 1.7 else 'occupied' if n > 1.5 else 'empty'
    print(f"  NO {i}: {n:.4f}  {bar}  ({label})")
# Out:
# Dipole moment
#   x: -0.000041 D
#   y: -0.000052 D
#   z: -0.000063 D
#   |μ| = 0.000091 D
#   (Should be ~0 by symmetry)
#
# Natural orbital occupations:
#   NO 0: 1.5617  ███████████████████████████████████████  (correlated)
#   NO 1: 0.9859  ████████████████████████  (correlated)
#   NO 2: 0.0053    (empty)

# %% [markdown]
# ---
#
# ## Summary: Energy Hierarchy
#
# Let's compare all the methods. Each layer of theory adds more accuracy:

# %%
# --- NEVPT2 ---
t0 = time.perf_counter()
try:
    nevpt2_corr = mrpt.NEVPT(cas).kernel()
    nevpt2_time = time.perf_counter() - t0
    nevpt2_e = casscf_e + nevpt2_corr
    print(f"ΔE(NEVPT2) = {nevpt2_corr:+.10f} Ha")
    print(f"E(CASSCF+NEVPT2) = {nevpt2_e:+.10f} Ha  ({nevpt2_time:.1f}s)")
except (AssertionError, RuntimeError, TypeError):
    nevpt2_e = None
    print("⚠ NEVPT2 requires a 3-RDM from the CI vector.")
    print("VQE solvers produce circuits, not CI vectors — skipping.")

# --- Summary ---
cas_fci = mcscf.CASCI(hf, norb, nelec)
cas_fci.verbose = 0
fci_e = cas_fci.kernel()[0]

print(f"\n{'Method':<22s}  {'Energy (Ha)':>14s}  {'Error to FCI':>12s}")
print(f"{'─' * 52}")
entries = [('HF', hf.e_tot), ('CASSCF (Maestro)', casscf_e)]
if nevpt2_e is not None:
    entries.append(('CASSCF + NEVPT2', nevpt2_e))
entries.append(('FCI (exact)', fci_e))
for label, e in entries:
    err = abs(e - fci_e) * 1000
    marker = ' ◀ GPU' if 'Maestro' in label else ''
    print(f"{label:<22s}  {e:+14.8f}  {err:10.2f} mHa{marker}")
# Out:
#   [MaestroSolver] Backend : CPU/QCSim (statevector)
#   [MaestroSolver] Qubits  : 6
#   [MaestroSolver] Ansatz  : hardware_efficient
#   [MaestroSolver] Params  : 24
#   [MaestroSolver] Paulis  : 117
#     iter    1  |  E = +0.9879607634
#     iter   20  |  E = +0.3815158352
#     iter   40  |  E = -0.6390832935
#     iter   60  |  E = -0.8176539746
#     iter   80  |  E = -0.9577334294
#     iter  100  |  E = -1.0075452609
#     iter  120  |  E = -1.0110974893
#     iter  140  |  E = -1.0214939925
#     iter  160  |  E = -1.0390287785
#     iter  180  |  E = -1.0497384361
#     iter  200  |  E = -1.0649683966
#   [MaestroSolver] Converged : False
#   [MaestroSolver] E(VQE)    : -1.0649683966
#   [MaestroSolver] E(total)  : -15.3478447369
#   [MaestroSolver] Time      : 0.13s
# ⚠ NEVPT2 requires a 3-RDM from the CI vector.
# VQE solvers produce circuits, not CI vectors — skipping.
#
# Method                     Energy (Ha)  Error to FCI
# ────────────────────────────────────────────────────
# HF                        -15.55983844        0.55 mHa
# CASSCF (Maestro)          -15.34959016      210.80 mHa ◀ GPU
# FCI (exact)               -15.56038754        0.00 mHa

# %% [markdown]
# ---
#
# ## Visualisation: Energy Ladder
#
# How does each method close the gap to exact (FCI) energy?

# %%
# Build lists, excluding NEVPT2 if it was skipped
methods = ['HF', 'CASSCF\n(Maestro VQE)', 'FCI\n(exact)']
energies = [hf.e_tot, casscf_e, fci_e]
colors = ['#f85149', '#d29922', '#58a6ff']
if nevpt2_e is not None:
    methods.insert(2, 'CASSCF +\nNEVPT2')
    energies.insert(2, nevpt2_e)
    colors.insert(2, '#3fb950')
errors = [abs(e - fci_e) * 1000 for e in energies]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5), gridspec_kw={'width_ratios': [3, 2]})

# --- Left: Energy ladder ---
bars = ax1.barh(methods, errors, color=colors, edgecolor='#30363d', height=0.6)
ax1.set_xlabel('Error to FCI (mHa)', fontsize=13)
ax1.set_title('Energy Error by Method', fontsize=15, fontweight='bold', pad=15)
ax1.invert_yaxis()
ax1.set_xlim(0, max(errors) * 1.15)

# Add value labels
for bar, err in zip(bars, errors):
    if err > 0.01:
        ax1.text(bar.get_width() + max(errors) * 0.02, bar.get_y() + bar.get_height() / 2,
                 f'{err:.1f} mHa', va='center', fontsize=11, color='#c9d1d9')
    else:
        ax1.text(max(errors) * 0.02, bar.get_y() + bar.get_height() / 2,
                 'exact', va='center', fontsize=11, color='#58a6ff', fontweight='bold')

# Chemical accuracy line
ax1.axvline(x=1.6, color='#f0883e', linestyle='--', linewidth=1.5, alpha=0.7)
ax1.text(1.6, -0.45, ' chemical\n accuracy', fontsize=9, color='#f0883e', va='top')

# --- Right: Absolute energies ---
y_pos = range(len(methods))
ax2.scatter(energies, y_pos, c=colors, s=120, zorder=5, edgecolors='#c9d1d9', linewidth=1)
ax2.set_xlabel('Total Energy (Ha)', fontsize=13)
ax2.set_title('Absolute Energies', fontsize=15, fontweight='bold', pad=15)
ax2.set_yticks(list(y_pos))
ax2.set_yticklabels(methods)
ax2.invert_yaxis()
ax2.grid(axis='x', alpha=0.3)

# FCI reference line
ax2.axvline(x=fci_e, color='#58a6ff', linestyle=':', linewidth=1, alpha=0.5)

for i, e in enumerate(energies):
    ax2.text(e, i - 0.3, f'{e:.4f}', fontsize=9, ha='center', color='#8b949e')

plt.tight_layout()
plt.savefig('energy_ladder.png', dpi=150, bbox_inches='tight', facecolor='#0d1117')
plt.show()
print('Saved: energy_ladder.png')
# Out:
# Saved: energy_ladder.png

# %% [markdown]
# ---
#
# ## Visualisation: VQE Convergence
#
# How did the VQE optimiser converge? The `energy_history` attribute tracks the energy at each iteration.

# %%
history = cas.fcisolver.energy_history

fig, ax = plt.subplots(figsize=(10, 5))

iters = np.arange(1, len(history) + 1)

# Main convergence curve
ax.plot(iters, history, color='#58a6ff', linewidth=2, label='VQE energy')

# Fill below the curve
ax.fill_between(iters, history, min(history) - 0.01 * abs(min(history)),
                alpha=0.1, color='#58a6ff')

# FCI reference line
ax.axhline(y=fci_e, color='#3fb950', linestyle='--', linewidth=1.5,
           label=f'FCI = {fci_e:.6f} Ha', alpha=0.8)

# Mark the final energy
final_e = history[-1]
ax.scatter([len(history)], [final_e], color='#f0883e', s=80, zorder=5,
           edgecolors='#c9d1d9', linewidth=1)
ax.annotate(f'Final: {final_e:.6f} Ha',
            xy=(len(history), final_e),
            xytext=(len(history) * 0.7, final_e + (history[0] - final_e) * 0.15),
            fontsize=10, color='#f0883e',
            arrowprops=dict(arrowstyle='->', color='#f0883e', lw=1.5))

ax.set_xlabel('VQE Iteration', fontsize=13)
ax.set_ylabel('Energy (Ha)', fontsize=13)
ax.set_title('VQE Convergence on Maestro', fontsize=15, fontweight='bold', pad=15)
ax.legend(loc='upper right', fontsize=11, framealpha=0.8,
          edgecolor='#30363d', facecolor='#161b22')
ax.grid(alpha=0.2)

plt.tight_layout()
plt.savefig('vqe_convergence.png', dpi=150, bbox_inches='tight', facecolor='#0d1117')
plt.show()
print(f'Converged in {len(history)} iterations')
print(f'Saved: vqe_convergence.png')

# %% [markdown]
# ---
#
# ## Visualisation: Natural Orbital Occupations
#
# Natural orbital occupations reveal the multi-reference character of the wavefunction. Occupations near 2.0 or 0.0 are "boring" (HF gets them right). Fractional occupations flag the correlated orbitals that justify using a quantum solver.

# %%
fig, ax = plt.subplots(figsize=(8, 5))

x = np.arange(len(occ))
labels = [f'NO {i}' for i in range(len(occ))]

# Colour by correlation character
bar_colors = []
for n in occ:
    if n > 1.7:
        bar_colors.append('#3fb950')   # occupied → green
    elif n < 0.3:
        bar_colors.append('#8b949e')   # empty → grey
    else:
        bar_colors.append('#f85149')   # correlated → red

bars = ax.bar(x, occ, color=bar_colors, edgecolor='#30363d', width=0.6)

# Reference lines
ax.axhline(y=2.0, color='#3fb950', linestyle=':', linewidth=1, alpha=0.4)
ax.axhline(y=0.0, color='#8b949e', linestyle=':', linewidth=1, alpha=0.4)

# Correlated bands
ax.axhspan(0.3, 1.7, alpha=0.05, color='#f85149')
ax.text(len(occ) - 0.5, 1.0, 'correlated\nregion', fontsize=9,
        color='#f85149', ha='center', va='center', alpha=0.7, fontstyle='italic')

# Value labels on bars
for bar, n in zip(bars, occ):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.05,
            f'{n:.3f}', ha='center', fontsize=11, color='#c9d1d9', fontweight='bold')

ax.set_xlabel('Natural Orbital', fontsize=13)
ax.set_ylabel('Occupation Number', fontsize=13)
ax.set_title('Natural Orbital Occupations (VQE)', fontsize=15, fontweight='bold', pad=15)
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.set_ylim(-0.1, 2.3)
ax.grid(axis='y', alpha=0.2)

# Legend
from matplotlib.patches import Patch
legend_elements = [
    Patch(facecolor='#3fb950', edgecolor='#30363d', label='Occupied (≈2.0)'),
    Patch(facecolor='#f85149', edgecolor='#30363d', label='Correlated (0.3–1.7)'),
    Patch(facecolor='#8b949e', edgecolor='#30363d', label='Empty (≈0.0)'),
]
ax.legend(handles=legend_elements, loc='upper right', fontsize=10,
          framealpha=0.8, edgecolor='#30363d', facecolor='#161b22')

plt.tight_layout()
plt.savefig('natural_orbitals.png', dpi=150, bbox_inches='tight', facecolor='#0d1117')
plt.show()
print('Saved: natural_orbitals.png')

# %% [markdown]
# ---
#
# ## What Just Happened?
#
# Let's recap the full pipeline:
#
# | Step | Method | Runs on | What it captures |
# |------|--------|---------|------------------|
# | 1 | Molecule definition | — | Nuclear geometry |
# | 2 | Hartree-Fock | CPU | Mean-field energy, starting orbitals |
# | 3 | **CASSCF + VQE** | **Maestro GPU** | **Static correlation** (multi-reference character) |
# | 4 | NEVPT2 | CPU | Dynamic correlation (electron cusp) |
# | 5 | Properties | CPU | Dipole moment, natural orbital occupations |
#
# The quantum circuit is only involved in **Step 3** — everything else is classical. But that one step is critical: it captures the strongly-correlated physics that breaks mean-field methods.
#
# ### Why Maestro?
#
# - **GPU acceleration**: VQE evaluations run on NVIDIA GPUs via Maestro
# - **MPS mode**: For larger active spaces, use `simulation="mps"` to go beyond 30 qubits
# - **Drop-in replacement**: The VQE solver plugs directly into PySCF's standard CASSCF workflow
# - **No Qiskit needed**: Pure PySCF + Maestro stack

# %% [markdown]
# ---
#
# ## Next Steps
#
# Try modifying this notebook:
#
# 1. **Change the molecule**: Replace BeH₂ with H₂O, LiH, or N₂
# 2. **Increase the active space**: Use `norb=4, nelec=4` for 8 qubits
# 3. **Try UCCSD ansatz**: Change to `ansatz="uccsd"` for chemistry-motivated circuits
# 4. **Enable GPU**: Set `BACKEND = "gpu"` (requires a Maestro license key)
# 5. **Use MPS**: Add `simulation="mps", mps_bond_dim=64` for larger systems
#
# ```python
# # Example: H₂O with UCCSD on GPU MPS
# cas.fcisolver = MaestroSolver(
#     ansatz="uccsd",
#     backend="gpu",
#     simulation="mps",
#     mps_bond_dim=128,
# )
# ```
